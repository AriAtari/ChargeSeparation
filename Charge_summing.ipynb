# %%
# %reload_ext autoreload
# %autoreload 2
import numpy as np

import pandas as pd
from Padplane import *

# %%
cords = [[0.024,0.024],[0.027,0.027],[0.027,0.024],[0.024,0.027],[0.05,0.03],[0.035,0.065]]
ellist = []

for cor in cords:
    ellist.append(electron(cor[0],cor[1]))
for e in ellist:
    e.random()
testpad= padplane()

testpad.summing(ellist)
testpad.active()
# Out:
# pad 238 has 1893.0968386663426 columbs of charge
# pad 239 has 193.38597632868286 columbs of charge
# pad 240 has 4312.9077648308 columbs of charge
# pad 241 has 1.98041106 columbs of charge
# pad 271 has 2065.7348881389494 columbs of charge
# pad 272 has 2551.7983868275414 columbs of charge
# pad 273 has 1711.4600509960624 columbs of charge
# pad 274 has 0.0245699948 columbs of charge
# pad 305 has 2906.4393465959874 columbs of charge
# pad 306 has 1082.7458918612826 columbs of charge
# pad 307 has 2166.8845759016745 columbs of charge
# pad 317 has 5.76029614e-09 columbs of charge
# pad 351 has 4648.123522170779 columbs of charge
# pad 352 has 517.496065140467 columbs of charge
# pad 385 has 679.5168589054454 columbs of charge
# pad 386 has 3.4783251027e-11 columbs of charge
# pad 856 has 517.341855 columbs of charge
# pad 857 has 1.46854847e-15 columbs of charge
# pad 885 has 1768.4685091956947 columbs of charge
# pad 886 has 2647.925974959089 columbs of charge
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
draw(ellist)
len(testpad.padlist)
# Out:
# 1012

# %% [markdown]
# ### Pad guide
# ![image.png](attachment:image.png)

# %%
pointslist = []
valuesr = np.random.uniform(-rmax,rmax,points)

for r in valuesr:
        po = point(r*np.cos(np.random.uniform(0,np.pi)),r*np.cos(np.random.uniform(0,np.pi)))
        pointslist.append(po)
# Out:
# 0.0001001455444420361
